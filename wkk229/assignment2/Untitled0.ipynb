# %%
myfile = open('logsofar.txt','r')

# %%
myFilelines = myfile.readlines()

# %%
myFilelines
# Out:
# []

# %%
for line in myfile:
    myFilelines.append(line)

# %%
myFilelines
# Out:
# ['commit f220498760e845be957e21e889f6be512aa60ed6\n',
#  'Merge: f9f79ee a2fadd7\n',
#  'Author: Nivan Ferreira <nivan.ferreira@gmail.com>\n',
#  'Date:   Fri Sep 20 10:27:36 2013 -0400\n',
#  '\n',
#  "    Merge branch 'master' of github.com:nyucusp/gx5003-fall2013\n",
#  '\n',
#  'commit f9f79ee4202610a45380fbac589e31b7df8db6f5\n',
#  'Author: Nivan Ferreira <nivan.ferreira@gmail.com>\n',
#  'Date:   Fri Sep 20 10:27:31 2013 -0400\n',
#  '\n',
#  '    creating lecture3 directory\n',
#  '\n',
#  'commit a2fadd736d9705d5d86aeb175de1275319da70d9\n',
#  'Author: ke638 <elliott.katherine.s@gmail.com>\n',
#  'Date:   Fri Sep 20 10:21:57 2013 -0400\n',
#  '\n',
#  '    Update Problem 1.py\n',
#  '    \n',
#  '    made folder added title\n',
#  '\n',
#  'commit b3887b52c18a3f0bdbe1a91bdd49322eb35ac2cd\n',
#  'Author: Katherine Elliot <ellliott.katherine.s@gmail.com>\n',
#  'Date:   Fri Sep 20 10:20:01 2013 -0400\n',
#  '\n',
#  '    updated\n',
#  '\n',
# ...

# %%
type(myFilelines)
# Out:
# list

# %%
myFilelines= []

# %%
argv = "09/19/2013 09:12:15"

# %%
myfile= open ('logAfterAssignment1.txt','r')

# %%
type(myfile)
# Out:
# file

# %%
from dateutil import parser

# %%
from datetime import datetime

# %%
argv
# Out:
# '09/19/2013 09:12:15'

# %%
dateOfInterest = parser.parse(argv)

# %%
dateOfInterest
# Out:
# datetime.datetime(2013, 9, 19, 9, 12, 15)

# %%
myFilelines
# Out:
# ['commit f220498760e845be957e21e889f6be512aa60ed6\n',
#  'Merge: f9f79ee a2fadd7\n',
#  'Author: Nivan Ferreira <nivan.ferreira@gmail.com>\n',
#  'Date:   Fri Sep 20 10:27:36 2013 -0400\n',
#  '\n',
#  "    Merge branch 'master' of github.com:nyucusp/gx5003-fall2013\n",
#  '\n',
#  'commit f9f79ee4202610a45380fbac589e31b7df8db6f5\n',
#  'Author: Nivan Ferreira <nivan.ferreira@gmail.com>\n',
#  'Date:   Fri Sep 20 10:27:31 2013 -0400\n',
#  '\n',
#  '    creating lecture3 directory\n',
#  '\n',
#  'commit a2fadd736d9705d5d86aeb175de1275319da70d9\n',
#  'Author: ke638 <elliott.katherine.s@gmail.com>\n',
#  'Date:   Fri Sep 20 10:21:57 2013 -0400\n',
#  '\n',
#  '    Update Problem 1.py\n',
#  '    \n',
#  '    made folder added title\n',
#  '\n',
#  'commit b3887b52c18a3f0bdbe1a91bdd49322eb35ac2cd\n',
#  'Author: Katherine Elliot <ellliott.katherine.s@gmail.com>\n',
#  'Date:   Fri Sep 20 10:20:01 2013 -0400\n',
#  '\n',
#  '    updated\n',
#  '\n',
# ...

# %%
for line in myFilelines:
    if "Date:":
        print line
# Out:
# commit f220498760e845be957e21e889f6be512aa60ed6
#
# Merge: f9f79ee a2fadd7
#
# Author: Nivan Ferreira <nivan.ferreira@gmail.com>
#
# Date:   Fri Sep 20 10:27:36 2013 -0400
#
#
#
#     Merge branch 'master' of github.com:nyucusp/gx5003-fall2013
#
#
#
# commit f9f79ee4202610a45380fbac589e31b7df8db6f5
#
# Author: Nivan Ferreira <nivan.ferreira@gmail.com>
#
# Date:   Fri Sep 20 10:27:31 2013 -0400
#
#
#
#     creating lecture3 directory
#
#
#
# commit a2fadd736d9705d5d86aeb175de1275319da70d9
#
# Author: ke638 <elliott.katherine.s@gmail.com>
#
# Date:   Fri Sep 20 10:21:57 2013 -0400
#
#
#
#     Update Problem 1.py
#
#
#
#     made folder added title
#
#
#
# commit b3887b52c18a3f0bdbe1a91bdd49322eb35ac2cd
#
# Author: Katherine Elliot <ellliott.katherine.s@gmail.com>
#
# Date:   Fri Sep 20 10:20:01 2013 -0400
#
#
#
#     updated
#
#
#
# commit beaa1ff629e48d9037d127f0f91008952751f966
#
# Author: Rebecca Hillegass <rebecca.hillegass@gmail.com>
#
# Date:   Fri Sep 20 01:25:16 2013 -0400
#
#
# ...

# %%
line = "Date:   Fri Sep 20 10:27:36 2013 -0400"

# %%
line[8:-6]
# Out:
# 'Fri Sep 20 10:27:36 2013'
